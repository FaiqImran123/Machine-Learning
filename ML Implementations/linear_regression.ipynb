# %% [markdown]
# ## Linear Regression

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df =pd.read_csv("placement.csv")
df
# Out:
#      cgpa  package
# 0    6.89     3.26
# 1    5.12     1.98
# 2    7.82     3.25
# 3    7.42     3.67
# 4    6.94     3.57
# ..    ...      ...
# 195  6.93     2.46
# 196  5.89     2.57
# 197  7.21     3.24
# 198  7.63     3.96
# 199  6.22     2.33
#
# [200 rows x 2 columns]

# %%
plt.scatter(df["cgpa"], df["package"])

# %%
X =df.iloc[:, 0:1]
Y =df.iloc[:,1]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test =train_test_split(X, Y, test_size=0.2, random_state=1)

# %%
from sklearn.linear_model import LinearRegression
lr =LinearRegression()

# %%
# Training Model
lr.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
predicted =lr.predict((np.array([6.92]).reshape(1,1)))
print(f"Predicted: {predicted} Actaul: {Y_test.values[0]}")
# Out:
# Predicted: [2.9383335] Actaul: 3.09
# c:\Users\faiqi\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
plt.scatter(X, Y)
plt.plot(X, lr.predict(X), color="green")
plt.xlabel("Cgpa")
plt.ylabel("Pakage (lpa)")
# Out:
# Text(0, 0.5, 'Pakage (lpa)')
